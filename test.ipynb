# %%
import lseg.data as ld
import pandas as pd

# %%
ld.open_session()
# Out:
# <lseg.data.session.Definition object at 0x13f39c050 {name='workspace'}>

# %%
from src.modelling import TICKERS
print(TICKERS)
# Out:
# ['NVDA.O', 'AMD.O', 'TSM.N', 'KO.N', 'PEP.O', 'JPM.N', 'BAC.N', 'GS.N', 'MS.N', 'XOM.N', 'CVX.N', 'AMZN.O', 'MSFT.O', 'META.O', 'GOOGL.O', 'JNJ.O', 'PFE.O']

# %%
df = ld.get_history(
    ['JNJ.N','PFE.N'],
    fields=['TR.CompanyMarketCap'],
    start="2023-12-29",
    end="2024-01-01",
)

df
# Out:
# Company Market Cap                JNJ.N                PFE.N
# Date
# 2023-12-29          377316850898.799988  162560238676.679993
